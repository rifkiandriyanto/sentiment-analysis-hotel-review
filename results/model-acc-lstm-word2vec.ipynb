# %%
import matplotlib.pyplot as plt

# Data epoch
epochs = list(range(1, 21))

# Data training untuk setiap fold
train_losses_folds = [
    [0.5585, 0.4963, 0.4736, 0.4516, 0.4230, 0.3966, 0.3677, 0.3423, 0.3171, 0.2939, 
     0.2691, 0.2454, 0.2293, 0.2112, 0.1957, 0.1784, 0.1694, 0.1574, 0.1494, 0.1401],
    [0.5607, 0.5001, 0.4759, 0.4519, 0.4242, 0.3959, 0.3674, 0.3369, 0.3113, 0.2826, 
     0.2611, 0.2405, 0.2216, 0.2058, 0.1924, 0.1763, 0.1620, 0.1530, 0.1437, 0.1363],
    [0.5559, 0.4967, 0.4742, 0.4491, 0.4231, 0.3972, 0.3744, 0.3448, 0.3184, 0.2936, 
     0.2729, 0.2521, 0.2324, 0.2126, 0.1978, 0.1856, 0.1733, 0.1616, 0.1491, 0.1425],
    [0.5566, 0.4987, 0.4728, 0.4526, 0.4270, 0.4028, 0.3783, 0.3486, 0.3235, 0.2999, 
     0.2799, 0.2541, 0.2374, 0.2234, 0.2038, 0.1907, 0.1766, 0.1652, 0.1572, 0.1463],
    [0.5596, 0.4934, 0.4687, 0.4487, 0.4203, 0.3945, 0.3677, 0.3395, 0.3170, 0.2927, 
     0.2663, 0.2414, 0.2263, 0.2071, 0.1920, 0.1764, 0.1654, 0.1500, 0.1432, 0.1350]
]

train_accuracies_folds = [
    [0.7588, 0.7917, 0.8024, 0.8123, 0.8258, 0.8380, 0.8521, 0.8633, 0.8773, 0.8868, 
     0.8958, 0.9086, 0.9153, 0.9219, 0.9288, 0.9357, 0.9384, 0.9434, 0.9454, 0.9485],
    [0.7570, 0.7871, 0.7981, 0.8104, 0.8233, 0.8392, 0.8499, 0.8647, 0.8775, 0.8907, 
     0.9010, 0.9086, 0.9174, 0.9231, 0.9278, 0.9355, 0.9405, 0.9440, 0.9478, 0.9508],
    [0.7617, 0.7924, 0.8057, 0.8148, 0.8268, 0.8391, 0.8503, 0.8651, 0.8758, 0.8862, 
     0.8950, 0.9040, 0.9135, 0.9201, 0.9255, 0.9316, 0.9360, 0.9399, 0.9461, 0.9480],
    [0.7610, 0.7909, 0.8013, 0.8119, 0.8241, 0.8347, 0.8476, 0.8589, 0.8722, 0.8844, 
     0.8918, 0.9035, 0.9098, 0.9168, 0.9234, 0.9303, 0.9350, 0.9391, 0.9452, 0.9462],
    [0.7587, 0.7950, 0.8069, 0.8133, 0.8285, 0.8399, 0.8534, 0.8658, 0.8770, 0.8867, 
     0.8966, 0.9095, 0.9157, 0.9236, 0.9298, 0.9347, 0.9391, 0.9462, 0.9486, 0.9516]
]

# Data validation accuracy untuk setiap fold
val_accuracies = [
    0.7790, 0.8072, 0.8043, 0.8136, 0.8194
]

# Plotting training loss
plt.figure(figsize=(14, 7))
for i, train_losses in enumerate(train_losses_folds):
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label=f'Fold {i+1}')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Word2Vec-LSTM per Fold')
plt.legend()

# Plotting training accuracy
for i, train_accuracies in enumerate(train_accuracies_folds):
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label=f'Fold {i+1}')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Word2Vec-LSTM per Fold')
plt.legend()

plt.tight_layout()
plt.show()

# Plotting validation accuracy
plt.figure(figsize=(7, 7))
plt.plot(range(1, 6), val_accuracies, 'g', label='Validation Accuracy')
plt.xlabel('Validation Round')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy Word2Vec-LSTM per Fold')
plt.legend()

plt.tight_layout()
plt.show()
