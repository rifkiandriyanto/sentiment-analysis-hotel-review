# %%
import matplotlib.pyplot as plt

# Data epoch
epochs = list(range(1, 21))

# Data training untuk setiap fold
train_losses_folds = [
    [0.6317, 0.5533, 0.5374, 0.5250, 0.5145, 0.5080, 0.4987, 0.4943, 0.4855, 0.4786, 
     0.4682, 0.4623, 0.4559, 0.4460, 0.4394, 0.4305, 0.4240, 0.4149, 0.4044, 0.3963],
    [0.6340, 0.5618, 0.5431, 0.5334, 0.5214, 0.5169, 0.5099, 0.5045, 0.4976, 0.4925, 
     0.4841, 0.4786, 0.4718, 0.4624, 0.4522, 0.4430, 0.4343, 0.4262, 0.4167, 0.4074],
    [0.6287, 0.5509, 0.5372, 0.5239, 0.5145, 0.5067, 0.5002, 0.4966, 0.4881, 0.4835, 
     0.4739, 0.4686, 0.4643, 0.4566, 0.4499, 0.4426, 0.4317, 0.4273, 0.4192, 0.4101],
    [0.6321, 0.5605, 0.5405, 0.5292, 0.5209, 0.5130, 0.5059, 0.5008, 0.4915, 0.4860, 
     0.4829, 0.4730, 0.4643, 0.4590, 0.4498, 0.4408, 0.4333, 0.4242, 0.4174, 0.4050],
    [0.6362, 0.5597, 0.5406, 0.5300, 0.5203, 0.5126, 0.5052, 0.4974, 0.4918, 0.4834, 
     0.4761, 0.4692, 0.4617, 0.4527, 0.4450, 0.4356, 0.4277, 0.4200, 0.4121, 0.4012]
]

train_accuracies_folds = [
    [0.7201, 0.7672, 0.7736, 0.7795, 0.7836, 0.7865, 0.7914, 0.7918, 0.7973, 0.8009, 
     0.8073, 0.8084, 0.8122, 0.8159, 0.8184, 0.8227, 0.8268, 0.8322, 0.8365, 0.8409],
    [0.7161, 0.7587, 0.7670, 0.7717, 0.7764, 0.7789, 0.7814, 0.7836, 0.7854, 0.7902, 
     0.7942, 0.7983, 0.8003, 0.8054, 0.8103, 0.8141, 0.8198, 0.8245, 0.8290, 0.8323],
    [0.7213, 0.7652, 0.7740, 0.7801, 0.7824, 0.7848, 0.7862, 0.7923, 0.7949, 0.7932, 
     0.7984, 0.8016, 0.8029, 0.8099, 0.8111, 0.8157, 0.8212, 0.8227, 0.8251, 0.8313],
    [0.7154, 0.7616, 0.7690, 0.7755, 0.7773, 0.7807, 0.7832, 0.7866, 0.7912, 0.7932, 
     0.7955, 0.7994, 0.8035, 0.8074, 0.8128, 0.8159, 0.8206, 0.8256, 0.8284, 0.8361],
    [0.7123, 0.7602, 0.7679, 0.7730, 0.7758, 0.7802, 0.7814, 0.7859, 0.7906, 0.7936, 
     0.7972, 0.8024, 0.8057, 0.8116, 0.8152, 0.8187, 0.8226, 0.8253, 0.8326, 0.8371]
]

# Data validation accuracy untuk setiap fold
val_accuracies = [
    0.7236, 0.7918, 0.8058, 0.7760, 0.7933
]

# Plotting training loss
plt.figure(figsize=(14, 7))
for i, train_losses in enumerate(train_losses_folds):
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label=f'Fold {i+1}')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss FastText-LSTM per Fold')
plt.legend()

# Plotting training accuracy
for i, train_accuracies in enumerate(train_accuracies_folds):
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label=f'Fold {i+1}')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy FastText-LSTM per Fold')
plt.legend()

plt.tight_layout()
plt.show()

# Plotting validation accuracy
plt.figure(figsize=(7, 7))
plt.plot(range(1, 6), val_accuracies, 'g', label='Validation Accuracy')
plt.xlabel('Validation Round')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy FastText-LSTM per Fold')
plt.legend()

plt.tight_layout()
plt.show()
