# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_confusion_matrix(conf_matrix, title):
    plt.figure(figsize=(10, 7))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['Negative', 'Neutral', 'Positive'],
                yticklabels=['Negative', 'Neutral', 'Positive'])
    plt.title(title, fontsize=15)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.show()

# Confusion matrices
conf_matrix_fasttext = np.array([[2508, 488, 218], [264, 1296, 624], [270, 1273, 13550]])
conf_matrix_word2vec = np.array([[3023, 107, 84], [107, 1867, 210], [65, 362, 14666]])
conf_matrix_doc2vec = np.array([[3035, 87, 92], [108, 1873, 203], [74, 154, 14865]])

# Titles
title_fasttext = 'Confusion Matrix for Fasttext-BiLSTM-Attention'
title_word2vec = 'Confusion Matrix for Word2vec-BiLSTM-Attention'
title_doc2vec = 'Confusion Matrix for Doc2vec-BiLSTM-Attention'

# Plotting the confusion matrices
plot_confusion_matrix(conf_matrix_fasttext, title_fasttext)
plot_confusion_matrix(conf_matrix_word2vec, title_word2vec)
plot_confusion_matrix(conf_matrix_doc2vec, title_doc2vec)
