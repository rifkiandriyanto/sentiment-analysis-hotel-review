# %%
import matplotlib.pyplot as plt

# Data epoch
epochs = list(range(1, 21))

# Data training untuk setiap fold
train_losses_folds = [
    [0.5438, 0.4776, 0.4400, 0.3872, 0.3147, 0.2366, 0.1772, 0.1345, 0.1046, 0.0848,
     0.0683, 0.0586, 0.0520, 0.0448, 0.0381, 0.0357, 0.0320, 0.0300, 0.0293, 0.0270],
    [0.5333, 0.4661, 0.4272, 0.3774, 0.3119, 0.2428, 0.1813, 0.1392, 0.1103, 0.0861,
     0.0704, 0.0581, 0.0525, 0.0447, 0.0428, 0.0372, 0.0335, 0.0310, 0.0299, 0.0262],
    [0.5343, 0.4644, 0.4235, 0.3785, 0.3116, 0.2449, 0.1809, 0.1385, 0.1068, 0.0852,
     0.0716, 0.0588, 0.0525, 0.0425, 0.0398, 0.0369, 0.0363, 0.0288, 0.0272, 0.0259],
    [0.5355, 0.4705, 0.4338, 0.3837, 0.3143, 0.2420, 0.1817, 0.1423, 0.1115, 0.0892,
     0.0716, 0.0594, 0.0530, 0.0426, 0.0405, 0.0372, 0.0366, 0.0322, 0.0279, 0.0280],
    [0.5273, 0.4617, 0.4231, 0.3711, 0.3032, 0.2365, 0.1797, 0.1391, 0.1068, 0.0871,
     0.0706, 0.0606, 0.0532, 0.0466, 0.0414, 0.0349, 0.0310, 0.0304, 0.0268, 0.0279]
]

train_accuracies_folds = [
    [0.7690, 0.8009, 0.8156, 0.8407, 0.8769, 0.9113, 0.9376, 0.9519, 0.9628, 0.9701,
     0.9764, 0.9792, 0.9819, 0.9848, 0.9863, 0.9876, 0.9897, 0.9897, 0.9898, 0.9911],
    [0.7740, 0.8051, 0.8182, 0.8421, 0.8759, 0.9080, 0.9334, 0.9496, 0.9597, 0.9702,
     0.9758, 0.9789, 0.9813, 0.9843, 0.9852, 0.9878, 0.9881, 0.9893, 0.9895, 0.9910],
    [0.7720, 0.8070, 0.8221, 0.8448, 0.8784, 0.9076, 0.9351, 0.9511, 0.9615, 0.9698,
     0.9751, 0.9789, 0.9819, 0.9856, 0.9857, 0.9869, 0.9880, 0.9900, 0.9907, 0.9910],
    [0.7709, 0.8012, 0.8188, 0.8423, 0.8764, 0.9098, 0.9345, 0.9483, 0.9594, 0.9682,
     0.9751, 0.9784, 0.9817, 0.9856, 0.9862, 0.9873, 0.9870, 0.9889, 0.9906, 0.9901],
    [0.7770, 0.8080, 0.8245, 0.8493, 0.8796, 0.9120, 0.9348, 0.9503, 0.9624, 0.9700,
     0.9750, 0.9788, 0.9813, 0.9839, 0.9853, 0.9880, 0.9892, 0.9898, 0.9906, 0.9910]
]

# Data validation accuracy untuk setiap fold
val_accuracies = [
    0.8234, 0.8167, 0.8199, 0.8194, 0.8202
]

# Plotting training loss
plt.figure(figsize=(14, 7))
for i, train_losses in enumerate(train_losses_folds):
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label=f'Fold {i+1}')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Doc2vec-LSTM per Fold')
plt.legend()

# Plotting training accuracy
for i, train_accuracies in enumerate(train_accuracies_folds):
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label=f'Fold {i+1}')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Doc2vec-LSTM per Fold')
plt.legend()

plt.tight_layout()
plt.show()

# Plotting validation accuracy
plt.figure(figsize=(7, 7))
plt.plot(range(1, 6), val_accuracies, 'g', label='Validation Accuracy')
plt.xlabel('Validation Round')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy Doc2vec-LSTM per Fold')
plt.legend()

plt.tight_layout()
plt.show()
