# %%
import matplotlib.pyplot as plt

def plot_training_results(epochs, train_losses_folds, train_accuracies_folds, val_accuracies, loss_title, accuracy_title, val_accuracy_title):
    """
    Plot training results including training loss, training accuracy, and validation accuracy.

    Args:
    epochs (list): List of epochs.
    train_losses_folds (list of lists): List of training loss values for each fold.
    train_accuracies_folds (list of lists): List of training accuracy values for each fold.
    val_accuracies (list): List of validation accuracies for each fold.
    loss_title (str): Title for the training loss plot.
    accuracy_title (str): Title for the training accuracy plot.
    val_accuracy_title (str): Title for the validation accuracy plot.
    """
    # Plotting training loss
    plt.figure(figsize=(14, 7))
    for i, train_losses in enumerate(train_losses_folds):
        plt.subplot(1, 2, 1)
        plt.plot(epochs, train_losses, label=f'Fold {i+1}')
    
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(loss_title)
    plt.legend()
    
    # Plotting training accuracy
    for i, train_accuracies in enumerate(train_accuracies_folds):
        plt.subplot(1, 2, 2)
        plt.plot(epochs, train_accuracies, label=f'Fold {i+1}')
    
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(accuracy_title)
    plt.legend()
    
    plt.tight_layout()
    plt.show()

    # Plotting validation accuracy
    plt.figure(figsize=(7, 7))
    plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, 'g', label='Validation Accuracy')
    plt.xlabel('Validation Round')
    plt.ylabel('Accuracy')
    plt.title(val_accuracy_title)
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Example usage:
epochs = list(range(1, 21))

# %%
# Data training untuk setiap fold
train_losses_folds_fasttext = [
    [0.6117, 0.5440, 0.5296, 0.5211, 0.5126, 0.5021, 0.4945, 0.4855, 0.4769, 0.4661, 
     0.4566, 0.4454, 0.4355, 0.4235, 0.4129, 0.4017, 0.3888, 0.3796, 0.3680, 0.3567],
    [0.6171, 0.5520, 0.5381, 0.5288, 0.5207, 0.5114, 0.5041, 0.4939, 0.4862, 0.4758, 
     0.4665, 0.4561, 0.4464, 0.4372, 0.4271, 0.4171, 0.4046, 0.3916, 0.3811, 0.3704],
    [0.6093, 0.5441, 0.5319, 0.5225, 0.5141, 0.5068, 0.4995, 0.4910, 0.4829, 0.4726, 
     0.4632, 0.4567, 0.4459, 0.4388, 0.4285, 0.4197, 0.4089, 0.3989, 0.3879, 0.3764],
    [0.6148, 0.5498, 0.5348, 0.5251, 0.5179, 0.5090, 0.4988, 0.4918, 0.4822, 0.4736, 
     0.4633, 0.4534, 0.4413, 0.4327, 0.4229, 0.4120, 0.4011, 0.3905, 0.3796, 0.3680],
    [0.6148, 0.5505, 0.5382, 0.5272, 0.5184, 0.5093, 0.4996, 0.4898, 0.4805, 0.4721, 
     0.4617, 0.4528, 0.4412, 0.4323, 0.4212, 0.4125, 0.4009, 0.3909, 0.3800, 0.3682],
]

train_accuracies_folds_fasttext = [
    [0.7340, 0.7722, 0.7803, 0.7842, 0.7851, 0.7919, 0.7952, 0.7988, 0.8028, 0.8095, 
     0.8148, 0.8190, 0.8252, 0.8314, 0.8358, 0.8430, 0.8467, 0.8536, 0.8594, 0.8645],
    [0.7272, 0.7638, 0.7716, 0.7733, 0.7786, 0.7814, 0.7862, 0.7895, 0.7946, 0.8003, 
     0.8057, 0.8105, 0.8169, 0.8205, 0.8284, 0.8330, 0.8393, 0.8440, 0.8498, 0.8570],
    [0.7368, 0.7725, 0.7783, 0.7823, 0.7856, 0.7880, 0.7934, 0.7975, 0.7992, 0.8040, 
     0.8110, 0.8132, 0.8173, 0.8228, 0.8276, 0.8296, 0.8360, 0.8405, 0.8469, 0.8525],
    [0.7296, 0.7655, 0.7745, 0.7782, 0.7805, 0.7845, 0.7893, 0.7959, 0.8008, 0.8051, 
     0.8102, 0.8148, 0.8211, 0.8242, 0.8307, 0.8362, 0.8412, 0.8456, 0.8520, 0.8590],
    [0.7275, 0.7658, 0.7715, 0.7760, 0.7793, 0.7841, 0.7866, 0.7941, 0.7993, 0.8017, 
     0.8081, 0.8139, 0.8190, 0.8252, 0.8317, 0.8346, 0.8411, 0.8446, 0.8491, 0.8563],
]

# Data validation accuracy untuk setiap fold
val_accuracies_fasttext = [
    0.7041, 0.7970, 0.7999, 0.7796, 0.8036
]


plot_training_results(
    epochs, 
    train_losses_folds_fasttext, 
    train_accuracies_folds_fasttext, 
    val_accuracies_fasttext, 
    'Training Loss FastText-BiLSTM-Att per Fold', 
    'Training Accuracy FastText-BiLSTM-Att per Fold', 
    'Validation Accuracy FastText-BiLSTM-Att per Fold'
)

# %%
# Data training untuk setiap fold
train_losses_folds_word2vec = [
    [0.5466, 0.4880, 0.4604, 0.4311, 0.3979, 0.3615, 0.3262, 0.2911, 0.2588, 0.2283, 
     0.1999, 0.1732, 0.1507, 0.1291, 0.1127, 0.0955, 0.0808, 0.0673, 0.0564, 0.0478],
    [0.5501, 0.4944, 0.4625, 0.4274, 0.3923, 0.3555, 0.3194, 0.2850, 0.2533, 0.2224, 
     0.1948, 0.1701, 0.1468, 0.1262, 0.1070, 0.0918, 0.0767, 0.0661, 0.0542, 0.0460],
    [0.5472, 0.4892, 0.4636, 0.4347, 0.3997, 0.3657, 0.3289, 0.2932, 0.2609, 0.2309, 
     0.2021, 0.1755, 0.1511, 0.1304, 0.1114, 0.0953, 0.0798, 0.0670, 0.0554, 0.0462],
    [0.5460, 0.4914, 0.4643, 0.4311, 0.3949, 0.3604, 0.3255, 0.2929, 0.2603, 0.2303, 
     0.2033, 0.1763, 0.1519, 0.1309, 0.1119, 0.0953, 0.0803, 0.0673, 0.0549, 0.0465],
    [0.5453, 0.4885, 0.4592, 0.4273, 0.3904, 0.3543, 0.3200, 0.2880, 0.2552, 0.2278, 
     0.1996, 0.1737, 0.1504, 0.1299, 0.1095, 0.0940, 0.0799, 0.0648, 0.0542, 0.0448]
]

train_accuracies_folds_word2vec = [
    [0.7664, 0.7971, 0.8095, 0.8251, 0.8415, 0.8595, 0.8766, 0.8905, 0.9070, 0.9202, 
     0.9327, 0.9438, 0.9535, 0.9604, 0.9657, 0.9716, 0.9775, 0.9818, 0.9847, 0.9874],
    [0.7617, 0.7899, 0.8051, 0.8245, 0.8425, 0.8631, 0.8799, 0.8946, 0.9104, 0.9238, 
     0.9353, 0.9455, 0.9539, 0.9612, 0.9680, 0.9734, 0.9779, 0.9809, 0.9848, 0.9871],
    [0.7686, 0.7955, 0.8092, 0.8249, 0.8426, 0.8579, 0.8763, 0.8922, 0.9050, 0.9174, 
     0.9304, 0.9406, 0.9509, 0.9591, 0.9649, 0.9715, 0.9771, 0.9815, 0.9856, 0.9872],
    [0.7650, 0.7942, 0.8077, 0.8261, 0.8445, 0.8601, 0.8787, 0.8928, 0.9074, 0.9203, 
     0.9308, 0.9418, 0.9513, 0.9592, 0.9655, 0.9705, 0.9762, 0.9809, 0.9844, 0.9872],
    [0.7673, 0.7968, 0.8101, 0.8257, 0.8453, 0.8629, 0.8810, 0.8958, 0.9113, 0.9215, 
     0.9319, 0.9416, 0.9510, 0.9572, 0.9661, 0.9717, 0.9765, 0.9812, 0.9846, 0.9875]
]

# Data validation accuracy untuk setiap fold
val_accuracies_word2vec = [
    0.7958, 0.7936, 0.7767, 0.8033, 0.8206
]


plot_training_results(
    epochs, 
    train_losses_folds_word2vec, 
    train_accuracies_folds_word2vec, 
    val_accuracies_word2vec, 
    'Training Loss Word2Vec-BiLSTM-Att per Fold', 
    'Training Accuracy Word2Vec-BiLSTM-Att per Fold', 
    'Validation Accuracy Word2Vec-BiLSTM-Att per Fold'
)

# %%
# Data training untuk setiap fold
train_losses_folds_doc2vec = [
    [0.5349, 0.4804, 0.4363, 0.3530, 0.2437, 0.1496, 0.0876, 0.0488, 0.0263, 0.0133, 
     0.0080, 0.0054, 0.0049, 0.0032, 0.0020, 0.0043, 0.0006, 0.0028, 0.0003, 0.0031],
    [0.5216, 0.4659, 0.4252, 0.3469, 0.2377, 0.1468, 0.0870, 0.0481, 0.0255, 0.0141, 
     0.0082, 0.0051, 0.0040, 0.0023, 0.0047, 0.0026, 0.0013, 0.0009, 0.0032, 0.0006],
    [0.5221, 0.4673, 0.4234, 0.3449, 0.2470, 0.1580, 0.0942, 0.0532, 0.0276, 0.0144, 
     0.0088, 0.0059, 0.0041, 0.0015, 0.0041, 0.0030, 0.0004, 0.0035, 0.0002, 0.0033],
    [0.5276, 0.4737, 0.4310, 0.3505, 0.2442, 0.1527, 0.0893, 0.0490, 0.0254, 0.0139, 
     0.0079, 0.0045, 0.0044, 0.0024, 0.0025, 0.0039, 0.0008, 0.0024, 0.0016, 0.0012],
    [0.5254, 0.4693, 0.4262, 0.3475, 0.2449, 0.1556, 0.0927, 0.0521, 0.0284, 0.0147, 
     0.0085, 0.0060, 0.0037, 0.0038, 0.0013, 0.0041, 0.0016, 0.0017, 0.0024, 0.0004]
]

train_accuracies_folds_doc2vec = [
    [0.7753, 0.7983, 0.8186, 0.8614, 0.9155, 0.9538, 0.9758, 0.9885, 0.9946, 0.9982, 
     0.9989, 0.9993, 0.9990, 0.9994, 0.9997, 0.9990, 1.0000, 0.9991, 1.0000, 0.9989],
    [0.7820, 0.8061, 0.8210, 0.8642, 0.9160, 0.9546, 0.9757, 0.9882, 0.9952, 0.9975, 
     0.9989, 0.9995, 0.9993, 0.9998, 0.9989, 0.9993, 0.9999, 0.9999, 0.9987, 0.9999],
    [0.7859, 0.8073, 0.8285, 0.8685, 0.9148, 0.9503, 0.9735, 0.9868, 0.9947, 0.9978, 
     0.9987, 0.9989, 0.9993, 0.9999, 0.9991, 0.9993, 1.0000, 0.9991, 1.0000, 0.9993],
    [0.7772, 0.8012, 0.8209, 0.8634, 0.9158, 0.9527, 0.9748, 0.9883, 0.9953, 0.9977, 
     0.9988, 0.9997, 0.9992, 0.9996, 0.9995, 0.9989, 0.9999, 0.9991, 0.9997, 0.9995],
    [0.7789, 0.8028, 0.8230, 0.8647, 0.9135, 0.9520, 0.9733, 0.9871, 0.9942, 0.9977, 
     0.9989, 0.9991, 0.9994, 0.9991, 0.9999, 0.9988, 0.9998, 0.9998, 0.9993, 1.0000]
]

# Data validation accuracy untuk setiap fold
val_accuracies_doc2vec = [
    0.8078, 0.8243, 0.8184, 0.8189, 0.8248
]


plot_training_results(
    epochs, 
    train_losses_folds_doc2vec, 
    train_accuracies_folds_doc2vec, 
    val_accuracies_doc2vec, 
    'Training Loss Doc2vec-BiLSTM-Att per Fold', 
    'Training Accuracy Doc2vec-BiLSTM-Att per Fold', 
    'Validation Accuracy Doc2vec-BiLSTM-Att per Fold'
)
