# %%
import matplotlib.pyplot as plt

def plot_training_results(epochs, train_losses_folds, train_accuracies_folds, val_accuracies, loss_title, accuracy_title, val_accuracy_title):
    """
    Plot training results including training loss, training accuracy, and validation accuracy.

    Args:
    epochs (list): List of epochs.
    train_losses_folds (list of lists): List of training loss values for each fold.
    train_accuracies_folds (list of lists): List of training accuracy values for each fold.
    val_accuracies (list): List of validation accuracies for each fold.
    loss_title (str): Title for the training loss plot.
    accuracy_title (str): Title for the training accuracy plot.
    val_accuracy_title (str): Title for the validation accuracy plot.
    """
    # Plotting training loss
    plt.figure(figsize=(14, 7))
    for i, train_losses in enumerate(train_losses_folds):
        plt.subplot(1, 2, 1)
        plt.plot(epochs, train_losses, label=f'Fold {i+1}')
    
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(loss_title)
    plt.legend()
    
    # Plotting training accuracy
    for i, train_accuracies in enumerate(train_accuracies_folds):
        plt.subplot(1, 2, 2)
        plt.plot(epochs, train_accuracies, label=f'Fold {i+1}')
    
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(accuracy_title)
    plt.legend()
    
    plt.tight_layout()
    plt.show()

    # Plotting validation accuracy
    plt.figure(figsize=(7, 7))
    plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, 'g', label='Validation Accuracy')
    plt.xlabel('Validation Round')
    plt.ylabel('Accuracy')
    plt.title(val_accuracy_title)
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Example usage:
epochs = list(range(1, 21))

# %%
# Data training untuk setiap fold
train_losses_folds_fasttext = [
    [0.6162, 0.5461, 0.5280, 0.5161, 0.5036, 0.4971, 0.4876, 0.4760, 0.4627, 0.4501, 
     0.4398, 0.4298, 0.4170, 0.4033, 0.3929, 0.3785, 0.3632, 0.3496, 0.3357, 0.3211],
    [0.6246, 0.5534, 0.5339, 0.5230, 0.5155, 0.5066, 0.4964, 0.4876, 0.4764, 0.4628, 
     0.4514, 0.4371, 0.4261, 0.4131, 0.4013, 0.3873, 0.3710, 0.3584, 0.3440, 0.3312],
    [0.6170, 0.5471, 0.5289, 0.5173, 0.5087, 0.4983, 0.4890, 0.4812, 0.4709, 0.4634, 
     0.4516, 0.4392, 0.4313, 0.4194, 0.4062, 0.3938, 0.3801, 0.3645, 0.3528, 0.3393],
    [0.6222, 0.5560, 0.5344, 0.5212, 0.5133, 0.5045, 0.4968, 0.4852, 0.4768, 0.4674, 
     0.4567, 0.4480, 0.4353, 0.4225, 0.4087, 0.3952, 0.3809, 0.3656, 0.3481, 0.3372],
    [0.6213, 0.5545, 0.5365, 0.5221, 0.5118, 0.5012, 0.4911, 0.4795, 0.4699, 0.4558, 
     0.4460, 0.4329, 0.4218, 0.4101, 0.3990, 0.3855, 0.3725, 0.3576, 0.3467, 0.3314]
]

train_accuracies_folds_fasttext = [
    [0.7291, 0.7705, 0.7796, 0.7830, 0.7888, 0.7930, 0.7969, 0.8013, 0.8060, 0.8124, 
     0.8198, 0.8224, 0.8288, 0.8360, 0.8401, 0.8484, 0.8574, 0.8623, 0.8684, 0.8738],
    [0.7219, 0.7613, 0.7694, 0.7735, 0.7770, 0.7828, 0.7871, 0.7911, 0.7972, 0.8049, 
     0.8109, 0.8172, 0.8254, 0.8298, 0.8362, 0.8431, 0.8509, 0.8563, 0.8638, 0.8698],
    [0.7282, 0.7680, 0.7793, 0.7804, 0.7839, 0.7884, 0.7932, 0.7949, 0.8003, 0.8055, 
     0.8121, 0.8171, 0.8218, 0.8250, 0.8312, 0.8386, 0.8437, 0.8506, 0.8578, 0.8621],
    [0.7273, 0.7625, 0.7719, 0.7772, 0.7807, 0.7845, 0.7888, 0.7926, 0.7995, 0.8014, 
     0.8068, 0.8117, 0.8195, 0.8248, 0.8323, 0.8398, 0.8461, 0.8524, 0.8622, 0.8680],
    [0.7211, 0.7596, 0.7701, 0.7746, 0.7794, 0.7836, 0.7896, 0.7953, 0.8014, 0.8082, 
     0.8137, 0.8211, 0.8265, 0.8330, 0.8373, 0.8446, 0.8491, 0.8562, 0.8632, 0.8692]
]

# Data validation accuracy untuk setiap fold
val_accuracies_fasttext = [
    0.7634, 0.8026, 0.7789, 0.7782, 0.7787
]


plot_training_results(
    epochs, 
    train_losses_folds_fasttext, 
    train_accuracies_folds_fasttext, 
    val_accuracies_fasttext, 
    'Training Loss FastText-BiLSTM per Fold', 
    'Training Accuracy FastText-BiLSTM per Fold', 
    'Validation Accuracy FastText-BiLSTM per Fold'
)

# %%
# Data training untuk setiap fold
train_losses_folds_word2vec = [
    [0.5443, 0.4850, 0.4529, 0.4195, 0.3847, 0.3443, 0.3032, 0.2704, 0.2362, 0.2059,
     0.1831, 0.1603, 0.1426, 0.1244, 0.1125, 0.1036, 0.0907, 0.0829, 0.0740, 0.0678],
    [0.5496, 0.4860, 0.4527, 0.4179, 0.3755, 0.3356, 0.2990, 0.2645, 0.2338, 0.2043,
     0.1799, 0.1640, 0.1403, 0.1259, 0.1117, 0.0991, 0.0895, 0.0804, 0.0739, 0.0679],
    [0.5485, 0.4868, 0.4534, 0.4134, 0.3765, 0.3354, 0.2958, 0.2630, 0.2333, 0.2055,
     0.1813, 0.1610, 0.1433, 0.1270, 0.1142, 0.0999, 0.0944, 0.0811, 0.0757, 0.0666],
    [0.5500, 0.4927, 0.4576, 0.4220, 0.3825, 0.3442, 0.3066, 0.2689, 0.2336, 0.2062,
     0.1810, 0.1621, 0.1404, 0.1266, 0.1113, 0.1012, 0.0927, 0.0810, 0.0740, 0.0665],
    [0.5460, 0.4835, 0.4482, 0.4114, 0.3711, 0.3309, 0.2930, 0.2573, 0.2290, 0.2008,
     0.1742, 0.1556, 0.1378, 0.1241, 0.1082, 0.0949, 0.0856, 0.0795, 0.0707, 0.0652]
]

train_accuracies_folds_word2vec = [
    [0.7674, 0.7972, 0.8109, 0.8278, 0.8425, 0.8616, 0.8823, 0.8966, 0.9107, 0.9230,
     0.9331, 0.9417, 0.9477, 0.9560, 0.9593, 0.9629, 0.9690, 0.9703, 0.9746, 0.9760],
    [0.7615, 0.7934, 0.8077, 0.8251, 0.8454, 0.8638, 0.8822, 0.8973, 0.9092, 0.9232,
     0.9322, 0.9401, 0.9484, 0.9549, 0.9597, 0.9645, 0.9677, 0.9712, 0.9740, 0.9760],
    [0.7663, 0.7972, 0.8103, 0.8298, 0.8479, 0.8665, 0.8837, 0.8986, 0.9099, 0.9217,
     0.9332, 0.9403, 0.9474, 0.9534, 0.9583, 0.9648, 0.9663, 0.9714, 0.9740, 0.9771],
    [0.7618, 0.7909, 0.8052, 0.8229, 0.8421, 0.8619, 0.8790, 0.8964, 0.9120, 0.9224,
     0.9341, 0.9402, 0.9492, 0.9544, 0.9599, 0.9633, 0.9670, 0.9708, 0.9749, 0.9774],
    [0.7644, 0.7998, 0.8126, 0.8302, 0.8506, 0.8692, 0.8842, 0.9016, 0.9127, 0.9245,
     0.9359, 0.9434, 0.9503, 0.9557, 0.9618, 0.9663, 0.9706, 0.9715, 0.9753, 0.9763]
]

# Data validation accuracy untuk setiap fold
val_accuracies_word2vec = [
    0.7943, 0.8365, 0.8043, 0.8287, 0.8192
]


plot_training_results(
    epochs, 
    train_losses_folds_word2vec, 
    train_accuracies_folds_word2vec, 
    val_accuracies_word2vec, 
    'Training Loss Word2Vec-BiLSTM per Fold', 
    'Training Accuracy Word2Vec-BiLSTM per Fold', 
    'Validation Accuracy Word2Vec-BiLSTM per Fold'
)

# %%
# Data training untuk setiap fold
train_losses_folds_doc2vec = [
    [0.5285, 0.4609, 0.4038, 0.3201, 0.2230, 0.1435, 0.0951, 0.0627, 0.0439, 0.0348, 
     0.0261, 0.0205, 0.0201, 0.0148, 0.0161, 0.0139, 0.0111, 0.0123, 0.0095, 0.0095],
    [0.5228, 0.4556, 0.3959, 0.3144, 0.2181, 0.1458, 0.0926, 0.0607, 0.0436, 0.0339, 
     0.0247, 0.0226, 0.0163, 0.0168, 0.0137, 0.0166, 0.0110, 0.0130, 0.0110, 0.0099],
    [0.5243, 0.4519, 0.3960, 0.3073, 0.2106, 0.1381, 0.0908, 0.0602, 0.0437, 0.0326, 
     0.0236, 0.0230, 0.0197, 0.0145, 0.0142, 0.0140, 0.0112, 0.0103, 0.0117, 0.0085],
    [0.5298, 0.4614, 0.4024, 0.3141, 0.2190, 0.1465, 0.0963, 0.0630, 0.0457, 0.0328, 
     0.0261, 0.0233, 0.0203, 0.0169, 0.0148, 0.0153, 0.0128, 0.0116, 0.0102, 0.0098],
    [0.5235, 0.4527, 0.3958, 0.3095, 0.2176, 0.1443, 0.0934, 0.0632, 0.0425, 0.0312, 
     0.0253, 0.0227, 0.0214, 0.0147, 0.0167, 0.0127, 0.0137, 0.0119, 0.0112, 0.0101]
]

train_accuracies_folds_doc2vec = [
    [0.7771, 0.8056, 0.8336, 0.8734, 0.9179, 0.9497, 0.9665, 0.9782, 0.9851, 0.9878, 
     0.9911, 0.9930, 0.9931, 0.9946, 0.9946, 0.9951, 0.9965, 0.9958, 0.9969, 0.9966],
    [0.7778, 0.8076, 0.8345, 0.8756, 0.9200, 0.9486, 0.9679, 0.9787, 0.9847, 0.9881, 
     0.9915, 0.9924, 0.9944, 0.9944, 0.9953, 0.9949, 0.9961, 0.9958, 0.9963, 0.9971],
    [0.7775, 0.8111, 0.8365, 0.8815, 0.9221, 0.9513, 0.9672, 0.9793, 0.9850, 0.9887, 
     0.9914, 0.9916, 0.9933, 0.9950, 0.9956, 0.9949, 0.9961, 0.9964, 0.9957, 0.9973],
    [0.7756, 0.8040, 0.8304, 0.8788, 0.9194, 0.9479, 0.9661, 0.9777, 0.9840, 0.9887, 
     0.9907, 0.9920, 0.9929, 0.9943, 0.9951, 0.9949, 0.9953, 0.9959, 0.9964, 0.9968],
    [0.7766, 0.8080, 0.8358, 0.8798, 0.9191, 0.9482, 0.9676, 0.9784, 0.9853, 0.9893, 
     0.9916, 0.9915, 0.9930, 0.9948, 0.9942, 0.9955, 0.9955, 0.9960, 0.9962, 0.9964]
]

# Data validation accuracy untuk setiap fold
val_accuracies_doc2vec = [
    0.7963, 0.8175, 0.8143, 0.8202, 0.8258
]


plot_training_results(
    epochs, 
    train_losses_folds_doc2vec, 
    train_accuracies_folds_doc2vec, 
    val_accuracies_doc2vec, 
    'Training Loss Doc2vec-BiLSTM per Fold', 
    'Training Accuracy Doc2vec-BiLSTM per Fold', 
    'Validation Accuracy Doc2vec-BiLSTM per Fold'
)
