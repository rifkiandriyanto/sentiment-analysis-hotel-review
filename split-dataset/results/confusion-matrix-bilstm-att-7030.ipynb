# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_confusion_matrix(conf_matrix, title):
    plt.figure(figsize=(10, 7))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['Negative', 'Neutral', 'Positive'],
                yticklabels=['Negative', 'Neutral', 'Positive'])
    plt.title(title, fontsize=15)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.show()

# Confusion matrices (new data)
conf_matrix_fasttext = np.array([[787, 126, 42], [192, 307, 146], [182, 495, 3871]])
conf_matrix_word2vec = np.array([[663, 262, 30], [126, 427, 92], [88, 768, 3692]])
conf_matrix_doc2vec = np.array([[673, 174, 108], [147, 244, 254], [135, 388, 4025]])

# Titles
title_fasttext = 'Confusion Matrix for BiLSTM-Attention-Fasttext'
title_word2vec = 'Confusion Matrix for BiLSTM-Attention-Word2vec'
title_doc2vec = 'Confusion Matrix for BiLSTM-Attention-Doc2vec'

# Plotting the confusion matrices
plot_confusion_matrix(conf_matrix_fasttext, title_fasttext)
plot_confusion_matrix(conf_matrix_word2vec, title_word2vec)
plot_confusion_matrix(conf_matrix_doc2vec, title_doc2vec)
