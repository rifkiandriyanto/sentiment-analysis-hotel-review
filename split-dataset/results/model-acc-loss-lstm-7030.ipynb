# %%
import matplotlib.pyplot as plt

def plot_training_results(epochs, train_losses, train_accuracies, loss_title, accuracy_title):
    """
    Plot training results including training loss and training accuracy.
    Args:
    epochs (list): List of epochs.
    train_losses (list): List of training loss values.
    train_accuracies (list): List of training accuracy values.
    loss_title (str): Title for the training loss plot.
    accuracy_title (str): Title for the training accuracy plot.
    """
    plt.figure(figsize=(14, 7))

    # Plotting training loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Training Loss', color='b', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(loss_title)
    plt.legend()

    # Plotting training accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Training Accuracy', color='g', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(accuracy_title)
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
epochs = list(range(1, 21))

# %%
# Data Loss dan Accuracy per Epoch
train_losses = [
    0.7672, 0.6471, 0.6272, 0.6188, 0.6088, 0.6036, 0.6028, 0.5988, 0.5932, 0.5925,
    0.5873, 0.5869, 0.5828, 0.5822, 0.5788, 0.5743, 0.5701, 0.5695, 0.5670, 0.5682
]

train_accuracies = [
    0.7623, 0.7753, 0.7848, 0.7839, 0.7852, 0.7927, 0.7906, 0.7887, 0.7911, 0.7899,
    0.7933, 0.7905, 0.7928, 0.7894, 0.7939, 0.7954, 0.7958, 0.7930, 0.7924, 0.7933
]

plot_training_results(
    epochs, 
    train_losses, 
    train_accuracies, 
    'Training Loss LSTM-FastText per Epoch', 
    'Training Accuracy LSTM-FastText per Epoch'
)

# %%
# Data training untuk setiap fold
train_losses = [
    0.6631, 0.5909, 0.5753, 0.5591, 0.5588, 0.5474, 0.5418, 0.5320, 0.5307, 0.5218,
    0.5186, 0.5130, 0.5006, 0.4989, 0.4879, 0.4805, 0.4747, 0.4701, 0.4553, 0.4550
]

train_accuracies = [
    0.7845, 0.7988, 0.8069, 0.8042, 0.8072, 0.8112, 0.8126, 0.8131, 0.8137, 0.8187,
    0.8183, 0.8189, 0.8184, 0.8194, 0.8241, 0.8249, 0.8270, 0.8286, 0.8302, 0.8320
]


plot_training_results(
    epochs, 
    train_losses, 
    train_accuracies, 
    'Training Loss LSTM-Word2vec per Epoch', 
    'Training Accuracy LSTM-Word2vec per Epoch'
)

# %%
# Data training untuk setiap fold
train_losses = [
    0.7122, 0.6147, 0.5976, 0.5849, 0.5768, 0.5708, 0.5557, 0.5411, 0.5275, 0.5134,
    0.4923, 0.4707, 0.4521, 0.4212, 0.3987, 0.3593, 0.3313, 0.3042, 0.2585, 0.2327
]

train_accuracies = [
    0.7777, 0.7895, 0.7929, 0.7938, 0.7947, 0.7951, 0.8013, 0.8004, 0.8079, 0.8073,
    0.8157, 0.8191, 0.8233, 0.8336, 0.8435, 0.8541, 0.8660, 0.8768, 0.8919, 0.9039
]


plot_training_results(
    epochs, 
    train_losses, 
    train_accuracies, 
    'Training Loss LSTM-Doc2vec per Epoch', 
    'Training Accuracy LSTM-Doc2vec per Epoch'
)
