# %%
import matplotlib.pyplot as plt

def plot_training_results(epochs, train_losses, train_accuracies, loss_title, accuracy_title):
    """
    Plot training results including training loss and training accuracy.
    Args:
    epochs (list): List of epochs.
    train_losses (list): List of training loss values.
    train_accuracies (list): List of training accuracy values.
    loss_title (str): Title for the training loss plot.
    accuracy_title (str): Title for the training accuracy plot.
    """
    plt.figure(figsize=(14, 7))

    # Plotting training loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Training Loss', color='b', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(loss_title)
    plt.legend()

    # Plotting training accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Training Accuracy', color='g', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(accuracy_title)
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
epochs = list(range(1, 21))

# %%
train_losses = [
    0.7389, 0.6377, 0.6201, 0.6111, 0.6122, 0.6035, 0.5948, 0.5921, 0.5937, 0.5917,
    0.5823, 0.5747, 0.5755, 0.5712, 0.5729, 0.5675, 0.5649, 0.5627, 0.5573, 0.5538
]

train_accuracies = [
    0.7568, 0.7836, 0.7826, 0.7879, 0.7883, 0.7876, 0.7904, 0.7860, 0.7851, 0.7893,
    0.7941, 0.7962, 0.7976, 0.7931, 0.7940, 0.7931, 0.7998, 0.7977, 0.7939, 0.7957
]

plot_training_results(
    epochs, 
    train_losses, 
    train_accuracies, 
    'Training Loss BiLSTM-FastText per Epoch', 
    'Training Accuracy BiLSTM-FastText per Epoch'
)

# %%
# Data training untuk setiap fold
train_losses = [
    0.6516, 0.5869, 0.5706, 0.5599, 0.5502, 0.5427, 0.5353, 0.5323, 0.5239, 0.5061,
    0.5101, 0.4992, 0.4876, 0.4780, 0.4740, 0.4578, 0.4497, 0.4388, 0.4292, 0.4208
]

train_accuracies = [
    0.7756, 0.7975, 0.8027, 0.8020, 0.8136, 0.8108, 0.8124, 0.8136, 0.8143, 0.8141,
    0.8138, 0.8158, 0.8202, 0.8230, 0.8267, 0.8308, 0.8300, 0.8302, 0.8350, 0.8380
]

plot_training_results(
    epochs, 
    train_losses, 
    train_accuracies, 
    'Training Loss BiLSTM-Word2vec per Epoch', 
    'Training Accuracy BiLSTM-Word2vec per Epoch'
)

# %%
# Data training untuk setiap fold
train_losses = [
    0.6837, 0.6099, 0.5883, 0.5791, 0.5676, 0.5505, 0.5365, 0.5147, 0.4930, 0.4645,
    0.4338, 0.3968, 0.3632, 0.3116, 0.2657, 0.2327, 0.1904, 0.1504, 0.1344, 0.1089
]

train_accuracies = [
    0.7662, 0.7864, 0.7910, 0.7956, 0.8000, 0.7979, 0.8042, 0.8049, 0.8161, 0.8205,
    0.8288, 0.8397, 0.8514, 0.8720, 0.8875, 0.8993, 0.9186, 0.9323, 0.9429, 0.9536
]


plot_training_results(
    epochs, 
    train_losses, 
    train_accuracies, 
    'Training Loss BiLSTM-Doc2vec per Epoch', 
    'Training Accuracy BiLSTM-Doc2vec per Epoch'
)
