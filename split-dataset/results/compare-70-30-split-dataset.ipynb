# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
labels = [
    'FastText-LSTM', 'Word2Vec-LSTM', 'Doc2Vec-LSTM', 
    'FastText-BiLSTM', 'Word2Vec-BiLSTM', 'Doc2Vec-BiLSTM', 
    'FastText-BiLSTM-Attention', 'Word2Vec-BiLSTM-Attention', 'Doc2Vec-BiLSTM-Attention'
]

accuracy = [0.78, 0.80, 0.79, 0.80, 0.81, 0.81, 0.81, 0.78, 0.80]
weighted_avg_recall = [0.78, 0.80, 0.79, 0.80, 0.81, 0.81, 0.81, 0.78, 0.80]
weighted_avg_f1_score = [0.81, 0.82, 0.80, 0.81, 0.83, 0.81, 0.82, 0.81, 0.81]
macro_avg_recall = [0.73, 0.73, 0.67, 0.72, 0.72, 0.67, 0.72, 0.72, 0.66]
macro_avg_f1_score = [0.67, 0.69, 0.65, 0.67, 0.68, 0.65, 0.68, 0.67, 0.65]

x = np.arange(len(labels))  # the label locations
width = 0.13  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))
rects1 = ax.bar(x - 2*width, accuracy, width, label='Accuracy')
rects2 = ax.bar(x - width, weighted_avg_recall, width, label='Weighted Avg Recall')
rects3 = ax.bar(x, weighted_avg_f1_score, width, label='Weighted Avg F1-Score')
rects4 = ax.bar(x + width, macro_avg_recall, width, label='Macro Avg Recall')
rects5 = ax.bar(x + 2*width, macro_avg_f1_score, width, label='Macro Avg F1-Score')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Performance on 70/30 Split Dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')

# Move the legend to inside the plot area, at the bottom left
ax.legend(loc='lower left', bbox_to_anchor=(0, -0.01))

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Labels and data extraction from the reports
models = [
    'LSTM-fasttext', 'LSTM-word2vec', 'LSTM-doc2vec', 
    'BiLSTM-fasttext', 'BiLSTM-word2vec', 'BiLSTM-doc2vec', 
    'BiLSTM-att-fasttext', 'BiLSTM-att-word2vec', 'BiLSTM-att-doc2vec'
]

# Class-specific metrics for each model
precision_negative = [0.71, 0.75, 0.70, 0.63, 0.72, 0.68, 0.68, 0.76, 0.70]
precision_neutral = [0.29, 0.31, 0.29, 0.32, 0.32, 0.32, 0.33, 0.29, 0.30]
precision_positive = [0.97, 0.96, 0.93, 0.96, 0.96, 0.92, 0.95, 0.97, 0.92]

recall_negative = [0.80, 0.76, 0.68, 0.88, 0.77, 0.75, 0.82, 0.69, 0.70]
recall_neutral = [0.60, 0.61, 0.47, 0.44, 0.54, 0.38, 0.48, 0.66, 0.38]
recall_positive = [0.80, 0.83, 0.85, 0.83, 0.85, 0.88, 0.85, 0.81, 0.89]

f1_negative = [0.75, 0.76, 0.69, 0.74, 0.75, 0.71, 0.74, 0.72, 0.70]
f1_neutral = [0.39, 0.41, 0.36, 0.37, 0.40, 0.35, 0.39, 0.41, 0.34]
f1_positive = [0.88, 0.89, 0.89, 0.89, 0.90, 0.90, 0.90, 0.88, 0.90]

# Bar plot setup
x = np.arange(len(models))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(3, 1, figsize=(15, 18))  # 3 plots for precision, recall, f1

# Precision Plot
ax[0].bar(x - width, precision_negative, width, label='Negative')
ax[0].bar(x, precision_neutral, width, label='Neutral')
ax[0].bar(x + width, precision_positive, width, label='Positive')
ax[0].set_title('Precision by Class')
ax[0].set_xticks(x)
ax[0].set_xticklabels(models, rotation=45, ha="right")
ax[0].set_ylabel('Precision')
ax[0].legend()

# Recall Plot
ax[1].bar(x - width, recall_negative, width, label='Negative')
ax[1].bar(x, recall_neutral, width, label='Neutral')
ax[1].bar(x + width, recall_positive, width, label='Positive')
ax[1].set_title('Recall by Class')
ax[1].set_xticks(x)
ax[1].set_xticklabels(models, rotation=45, ha="right")
ax[1].set_ylabel('Recall')
ax[1].legend()

# F1-Score Plot
ax[2].bar(x - width, f1_negative, width, label='Negative')
ax[2].bar(x, f1_neutral, width, label='Neutral')
ax[2].bar(x + width, f1_positive, width, label='Positive')
ax[2].set_title('F1-Score by Class')
ax[2].set_xticks(x)
ax[2].set_xticklabels(models, rotation=45, ha="right")
ax[2].set_ylabel('F1-Score')
ax[2].legend()

# Adjust layout
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Models and data extraction from the reports
models = [
    'LSTM-fasttext', 'LSTM-word2vec', 'LSTM-doc2vec', 
    'BiLSTM-fasttext', 'BiLSTM-word2vec', 'BiLSTM-doc2vec', 
    'BiLSTM-att-fasttext', 'BiLSTM-att-word2vec', 'BiLSTM-att-doc2vec'
]

# Class-specific metrics for each model
precision_negative = [0.71, 0.75, 0.70, 0.63, 0.72, 0.68, 0.68, 0.76, 0.70]
precision_neutral = [0.29, 0.31, 0.29, 0.32, 0.32, 0.32, 0.33, 0.29, 0.30]
precision_positive = [0.97, 0.96, 0.93, 0.96, 0.96, 0.92, 0.95, 0.97, 0.92]

recall_negative = [0.80, 0.76, 0.68, 0.88, 0.77, 0.75, 0.82, 0.69, 0.70]
recall_neutral = [0.60, 0.61, 0.47, 0.44, 0.54, 0.38, 0.48, 0.66, 0.38]
recall_positive = [0.80, 0.83, 0.85, 0.83, 0.85, 0.88, 0.85, 0.81, 0.89]

f1_negative = [0.75, 0.76, 0.69, 0.74, 0.75, 0.71, 0.74, 0.72, 0.70]
f1_neutral = [0.39, 0.41, 0.36, 0.37, 0.40, 0.35, 0.39, 0.41, 0.34]
f1_positive = [0.88, 0.89, 0.89, 0.89, 0.90, 0.90, 0.90, 0.88, 0.90]

# Create the plot
x = np.arange(len(models))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(16, 8))

# Plot precision bars for each class
rects1 = ax.bar(x - width, precision_negative, width, label='Precision Negative')
rects2 = ax.bar(x, precision_neutral, width, label='Precision Neutral')
rects3 = ax.bar(x + width, precision_positive, width, label='Precision Positive')

# Plot recall bars for each class stacked on top of precision
rects4 = ax.bar(x - width, recall_negative, width, label='Recall Negative', bottom=precision_negative)
rects5 = ax.bar(x, recall_neutral, width, label='Recall Neutral', bottom=precision_neutral)
rects6 = ax.bar(x + width, recall_positive, width, label='Recall Positive', bottom=precision_positive)

# Plot F1-Score bars for each class stacked on top of recall
rects7 = ax.bar(x - width, f1_negative, width, label='F1 Negative', bottom=np.array(precision_negative) + np.array(recall_negative))
rects8 = ax.bar(x, f1_neutral, width, label='F1 Neutral', bottom=np.array(precision_neutral) + np.array(recall_neutral))
rects9 = ax.bar(x + width, f1_positive, width, label='F1 Positive', bottom=np.array(precision_positive) + np.array(recall_positive))

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Performance by Class (Precision, Recall, F1-Score)')
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45, ha="right")

# Add a legend
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Adjust layout to make room for the legend
fig.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the table
models = [
    'LSTM-fasttext', 'LSTM-word2vec', 'LSTM-doc2vec', 
    'BiLSTM-fasttext', 'BiLSTM-word2vec', 'BiLSTM-doc2vec', 
    'BiLSTM-att-fasttext', 'BiLSTM-att-word2vec', 'BiLSTM-att-doc2vec'
]

# Class-specific metrics for each model
precision_negative = [0.71, 0.75, 0.70, 0.63, 0.72, 0.68, 0.68, 0.76, 0.70]
precision_neutral = [0.29, 0.31, 0.29, 0.32, 0.32, 0.32, 0.33, 0.29, 0.30]
precision_positive = [0.97, 0.96, 0.93, 0.96, 0.96, 0.92, 0.95, 0.97, 0.92]

recall_negative = [0.80, 0.76, 0.68, 0.88, 0.77, 0.75, 0.82, 0.69, 0.70]
recall_neutral = [0.60, 0.61, 0.47, 0.44, 0.54, 0.38, 0.48, 0.66, 0.38]
recall_positive = [0.80, 0.83, 0.85, 0.83, 0.85, 0.88, 0.85, 0.81, 0.89]

f1_negative = [0.75, 0.76, 0.69, 0.74, 0.75, 0.71, 0.74, 0.72, 0.70]
f1_neutral = [0.39, 0.41, 0.36, 0.37, 0.40, 0.35, 0.39, 0.41, 0.34]
f1_positive = [0.88, 0.89, 0.89, 0.89, 0.90, 0.90, 0.90, 0.88, 0.90]

# Create the figure and the table
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_axis_off()  # Hide the plot axes

# Data for table
table_data = [
    ['Precision Negative'] + precision_negative,
    ['Precision Neutral'] + precision_neutral,
    ['Precision Positive'] + precision_positive,
    ['Recall Negative'] + recall_negative,
    ['Recall Neutral'] + recall_neutral,
    ['Recall Positive'] + recall_positive,
    ['F1-Score Negative'] + f1_negative,
    ['F1-Score Neutral'] + f1_neutral,
    ['F1-Score Positive'] + f1_positive
]

# Create table with data
table = ax.table(
    cellText=table_data,  # The data inside the table
    colLabels=["Metric"] + models,  # Headers
    loc='center',  # Positioning
    cellLoc='center',  # Center-align text
    colColours=['lightblue'] * (len(models) + 1),  # Color for columns
    colWidths=[0.15] * (len(models) + 1)  # Column width
)

# Auto-adjust the layout
table.scale(1, 2)  # Scale for better readability
fig.tight_layout()

# Show the table
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
labels = [
    'FastText-LSTM', 'Word2Vec-LSTM', 'Doc2Vec-LSTM', 
    'FastText-BiLSTM', 'Word2Vec-BiLSTM', 'Doc2Vec-BiLSTM', 
    'FastText-BiLSTM-Attention', 'Word2Vec-BiLSTM-Attention', 'Doc2Vec-BiLSTM-Attention'
]

accuracy = [0.83, 0.93, 0.96, 0.84, 0.95, 0.96, 0.85, 0.95, 0.96]
weighted_avg_recall = [0.83, 0.93, 0.96, 0.84, 0.95, 0.96, 0.85, 0.95, 0.96]
weighted_avg_f1_score = [0.85, 0.93, 0.96, 0.86, 0.95, 0.96, 0.86, 0.95, 0.96]
macro_avg_recall = [0.75, 0.90, 0.93, 0.80, 0.88, 0.92, 0.76, 0.92, 0.93]
macro_avg_f1_score = [0.73, 0.87, 0.93, 0.75, 0.90, 0.93, 0.74, 0.92, 0.93]

x = np.arange(len(labels))  # the label locations
width = 0.13  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))
rects1 = ax.bar(x - 2*width, accuracy, width, label='Accuracy')
rects2 = ax.bar(x - width, weighted_avg_recall, width, label='Weighted Avg Recall')
rects3 = ax.bar(x, weighted_avg_f1_score, width, label='Weighted Avg F1-Score')
rects4 = ax.bar(x + width, macro_avg_recall, width, label='Macro Avg Recall')
rects5 = ax.bar(x + 2*width, macro_avg_f1_score, width, label='Macro Avg F1-Score')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Performance on SMOTE and Stratified K-Fold')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')

# Move the legend to inside the plot area, at the bottom left
ax.legend(loc='lower left', bbox_to_anchor=(0, -0.01))

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
labels = [
    'FastText-LSTM', 'Word2Vec-LSTM', 'Doc2Vec-LSTM', 
    'FastText-BiLSTM', 'Word2Vec-BiLSTM', 'Doc2Vec-BiLSTM', 
    'FastText-BiLSTM-Attention', 'Word2Vec-BiLSTM-Attention', 'Doc2Vec-BiLSTM-Attention'
]
accuracy = [0.83, 0.93, 0.96, 0.84, 0.95, 0.96, 0.85, 0.95, 0.96]
weighted_avg_recall = [0.83, 0.93, 0.96, 0.84, 0.95, 0.96, 0.85, 0.95, 0.96]
weighted_avg_f1_score = [0.85, 0.93, 0.96, 0.86, 0.95, 0.96, 0.86, 0.95, 0.96]
macro_avg_recall = [0.75, 0.90, 0.93, 0.80, 0.88, 0.92, 0.76, 0.92, 0.93]
macro_avg_f1_score = [0.73, 0.87, 0.93, 0.75, 0.90, 0.93, 0.74, 0.92, 0.93]

x = np.arange(len(labels))  # the label locations
width = 0.14  # the width of the bars

fig, ax = plt.subplots(figsize=(14,10))
rects1 = ax.bar(x - 2*width, accuracy, width, label='Accuracy')
rects2 = ax.bar(x - width, weighted_avg_recall, width, label='Weighted Avg Recall')
rects3 = ax.bar(x, weighted_avg_f1_score, width, label='Weighted Avg F1-Score')
rects4 = ax.bar(x + width, macro_avg_recall, width, label='Macro Avg Recall')
rects5 = ax.bar(x + 2*width, macro_avg_f1_score, width, label='Macro Avg F1-Score')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores', fontsize=16)
ax.set_title('Comparison of Model Performance on SMOTE and Stratified K-Fold', fontsize=18)

ax.set_xlabel('Models', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right', fontsize=18)

# Move the legend to inside the plot area, at the bottom left
ax.legend(loc='lower left', bbox_to_anchor=(0, -0.01), fontsize=16)

# Adjust the margins
fig.subplots_adjust(left=0.05, right=0.95)

fig.tight_layout()
plt.show()
